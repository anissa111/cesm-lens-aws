# %% [markdown]
# # GeoCAT Scenario 1
#
# This jupyter notebook demonstrates how to use GeoCAT functionality for the NCAR
# Science at a Scale (S@S) efforts.
#
# Use data hosted on AWS S3

# %% [markdown]
# ## Set up environment

# %%
import warnings

warnings.filterwarnings("ignore")

import intake
import numpy as np
import pandas as pd
import xarray as xr
import geocat.comp

# %% [markdown]
# ## Create and Connect to Dask Distributed Cluster

# %%
from dask.distributed import Client

# Create cluster
from dask_gateway import Gateway

gateway = Gateway()
cluster = gateway.new_cluster()
cluster.adapt(minimum=2, maximum=100)
# Connect to cluster
client = Client(cluster)
# Display cluster dashboard URL
cluster
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-6855e011d64c> in <module>
#       4 from dask_gateway import Gateway
#       5
# ----> 6 gateway = Gateway()
#       7 cluster = gateway.new_cluster()
#       8 cluster.adapt(minimum=2, maximum=100)
#
# ~/opt/anaconda3/envs/scienceatscale/lib/python3.7/site-packages/dask_gateway/client.py in __init__(self, address, proxy_address, public_address, auth, asynchronous, loop)
#     280         if address is None:
#     281             raise ValueError(
# --> 282                 "No dask-gateway address provided or found in configuration"
#     283             )
#     284         address = address.rstrip("/")
#
# ValueError: No dask-gateway address provided or found in configuration

# %% [markdown]
# ## Load data into xarray from a catalog using intake-esm

# %%
catalog_url = "https://ncar-cesm-lens.s3-us-west-2.amazonaws.com/catalogs/aws-cesm1-le.json"
col = intake.open_esm_datastore(catalog_url)
col
# Out:
# <p><strong>aws-cesm1-le catalog with 56 dataset(s) from 435 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>variable</th>
#       <td>77</td>
#     </tr>
#     <tr>
#       <th>long_name</th>
#       <td>74</td>
#     </tr>
#     <tr>
#       <th>component</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>experiment</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>vertical_levels</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>spatial_domain</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>units</th>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>start_time</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>end_time</th>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>420</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Show the first few lines of the catalog
col.df.head(10)
# Out:
#   variable                                          long_name component  \
# 0     FLNS                       net longwave flux at surface       atm
# 1    FLNSC              clearsky net longwave flux at surface       atm
# 2     FLUT            upwelling longwave flux at top of model       atm
# 3     FSNS                          net solar flux at surface       atm
# 4    FSNSC                 clearsky net solar flux at surface       atm
# 5   FSNTOA                net solar flux at top of atmosphere       atm
# 6  ICEFRAC            fraction of sfc area covered by sea-ice       atm
# 7    LHFLX                           surface latent heat flux       atm
# 8    PRECL  large-scale (stable) precipitation rate (liq +...       atm
# 9   PRECSC            convective snow rate (water equivalent)       atm
#
#   experiment frequency  vertical_levels spatial_domain     units  \
# 0        20C     daily              1.0         global      W/m2
# 1        20C     daily              1.0         global      W/m2
# 2        20C     daily              1.0         global      W/m2
# 3        20C     daily              1.0         global      W/m2
# 4        20C     daily              1.0         global      W/m2
# 5        20C     daily              1.0         global      W/m2
# 6        20C     daily              1.0         global  fraction
# 7        20C     daily              1.0         global      W/m2
# 8        20C     daily              1.0         global       m/s
# 9        20C     daily              1.0         global       m/s
#
#             start_time             end_time  \
# 0  1920-01-01 12:00:00  2005-12-31 12:00:00
# 1  1920-01-01 12:00:00  2005-12-31 12:00:00
# 2  1920-01-01 12:00:00  2005-12-31 12:00:00
# 3  1920-01-01 12:00:00  2005-12-31 12:00:00
# 4  1920-01-01 12:00:00  2005-12-31 12:00:00
# 5  1920-01-01 12:00:00  2005-12-31 12:00:00
# 6  1920-01-01 12:00:00  2005-12-31 12:00:00
# 7  1920-01-01 12:00:00  2005-12-31 12:00:00
# 8  1920-01-01 12:00:00  2005-12-31 12:00:00
# 9  1920-01-01 12:00:00  2005-12-31 12:00:00
#
#                                                 path
# 0  s3://ncar-cesm-lens/atm/daily/cesmLE-20C-FLNS....
# 1  s3://ncar-cesm-lens/atm/daily/cesmLE-20C-FLNSC...
# 2  s3://ncar-cesm-lens/atm/daily/cesmLE-20C-FLUT....
# 3  s3://ncar-cesm-lens/atm/daily/cesmLE-20C-FSNS....
# 4  s3://ncar-cesm-lens/atm/daily/cesmLE-20C-FSNSC...
# 5  s3://ncar-cesm-lens/atm/daily/cesmLE-20C-FSNTO...
# 6  s3://ncar-cesm-lens/atm/daily/cesmLE-20C-ICEFR...
# 7  s3://ncar-cesm-lens/atm/daily/cesmLE-20C-LHFLX...
# 8  s3://ncar-cesm-lens/atm/daily/cesmLE-20C-PRECL...
# 9  s3://ncar-cesm-lens/atm/daily/cesmLE-20C-PRECS...

# %%
# Show expanded version of collection structure with details
import pprint

uniques = col.unique(
    columns=["component", "frequency", "experiment", "variable"]
)
pprint.pprint(uniques, compact=True, indent=4)
# Out:
# {   'component': {   'count': 5,
#                      'values': ['ocn', 'ice_sh', 'atm', 'ice_nh', 'lnd']},
#     'experiment': {'count': 4, 'values': ['RCP85', 'CTRL', 'HIST', '20C']},
#     'frequency': {   'count': 6,
#                      'values': [   'hourly6-2026-2035', 'monthly', 'static',
#                                    'hourly6-2071-2080', 'daily',
#                                    'hourly6-1990-2005']},
#     'variable': {   'count': 77,
#                     'values': [   'U', 'SOILLIQ', 'TAUY2', 'TMQ', 'hi',
#                                   'H2OSNO', 'UET', 'SFWF', 'TREFMNAV_U',
#                                   'ICEFRAC', 'UES', 'SHF_QSW', 'PRECT', 'VNS',
#                                   'LHFLX', 'TREFHT', 'QSW_HBL', 'PS', 'WTS',
#                                   'FLNS', 'PRECTMX', 'O2', 'UBOT', 'QBOT', 'Z3',
#                                   'FSNS', 'Q', 'T', 'TEMP', 'FW', 'VVEL',
#                                   'QSW_HTP', 'RAIN', 'PRECL', 'FSNO', 'TAUY',
#                                   'Z500', 'FSNSC', 'WSPDSRFAV', 'TS', 'VNT',
#                                   'SNOW', 'QRUNOFF', 'PRECSL', 'FLNSC', 'SHF',
#                                   'FSNTOA', 'FLUT', 'PRECSC', 'TAUX2', 'UVEL',
#                                   'SOILWATER_10CM', 'TAUX', 'PSL', 'VBOT',
#                                   'SFWF_WRST', 'PD', 'SSH', 'TREFHTMN', 'HMXL',
#                                   'SHFLX', 'TREFHTMX', 'aice_d', 'QFLUX',
#                                   'QREFHT', 'hi_d', 'WVEL', 'PRECC', 'RESID_S',
#                                   'DIC', 'DOC', 'aice', 'WTT', 'SST', 'SALT',
#                                   'TREFMXAV_U', 'Q850']}}

# %%
col_subset = col.search(
    frequency=["daily", "monthly"],
    component="atm",
    variable=["Q850","PS", "TS"],
    experiment=["20C", "RCP85", "HIST"],
)

col_subset
# Out:
# <p><strong>aws-cesm1-le catalog with 6 dataset(s) from 9 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>variable</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>long_name</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>component</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>experiment</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>vertical_levels</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>spatial_domain</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>units</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>start_time</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>end_time</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>9</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
col_subset.df
# Out:
#   variable                                       long_name component  \
# 0     Q850  specific humidity at 850 mbar pressure surface       atm
# 1       TS                 surface temperature (radiative)       atm
# 2     Q850  specific humidity at 850 mbar pressure surface       atm
# 3       TS                 surface temperature (radiative)       atm
# 4       TS                 surface temperature (radiative)       atm
# 5       TS                 surface temperature (radiative)       atm
# 6       TS                 surface temperature (radiative)       atm
# 7       PS                                surface pressure       atm
# 8       TS                 surface temperature (radiative)       atm
#
#   experiment frequency  vertical_levels spatial_domain  units  \
# 0        20C     daily              1.0         global  kg/kg
# 1        20C     daily              1.0         global      K
# 2       HIST     daily              1.0         global  kg/kg
# 3       HIST     daily              1.0         global      K
# 4      RCP85     daily              1.0         global      K
# 5        20C   monthly              1.0         global      K
# 6       HIST   monthly              1.0         global      K
# 7      RCP85   monthly              1.0         global     Pa
# 8      RCP85   monthly              1.0         global      K
#
#             start_time             end_time  \
# 0  1920-01-01 12:00:00  2005-12-31 12:00:00
# 1  1920-01-01 12:00:00  2005-12-31 12:00:00
# 2  1850-01-01 12:00:00  1919-12-31 12:00:00
# 3  1850-01-01 12:00:00  1919-12-31 12:00:00
# 4  2006-01-01 12:00:00  2100-12-31 12:00:00
# 5  1920-01-16 12:00:00  2005-12-16 12:00:00
# 6  1850-01-16 12:00:00  1919-12-16 12:00:00
# 7  2006-01-16 12:00:00  2100-12-16 12:00:00
# 8  2006-01-16 12:00:00  2100-12-16 12:00:00
#
#                                                 path
# 0  s3://ncar-cesm-lens/atm/daily/cesmLE-20C-Q850....
# 1   s3://ncar-cesm-lens/atm/daily/cesmLE-20C-TS.zarr
# 2  s3://ncar-cesm-lens/atm/daily/cesmLE-HIST-Q850...
# 3  s3://ncar-cesm-lens/atm/daily/cesmLE-HIST-TS.zarr
# 4  s3://ncar-cesm-lens/atm/daily/cesmLE-RCP85-TS....
# 5  s3://ncar-cesm-lens/atm/monthly/cesmLE-20C-TS....
# 6  s3://ncar-cesm-lens/atm/monthly/cesmLE-HIST-TS...
# 7  s3://ncar-cesm-lens/atm/monthly/cesmLE-RCP85-P...
# 8  s3://ncar-cesm-lens/atm/monthly/cesmLE-RCP85-T...
